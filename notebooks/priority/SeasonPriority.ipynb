# %%
from geebap import priority

# %%
from geetools import ui

# %%
sp2000 = priority.SeasonPriority(2000)

# %%
ui.eprint(sp2000.ee_relation)
# Out:
# { '1972': ['LANDSAT/LM01/C01/T1'],
#   '1973': ['LANDSAT/LM01/C01/T1'],
#   '1974': ['LANDSAT/LM02/C01/T1', 'LANDSAT/LM01/C01/T1'],
#   '1975': ['LANDSAT/LM02/C01/T1', 'LANDSAT/LM01/C01/T1'],
#   '1976': ['LANDSAT/LM03/C01/T1', 'LANDSAT/LM02/C01/T1', 'LANDSAT/LM01/C01/T1'],
#   '1977': ['LANDSAT/LM03/C01/T1', 'LANDSAT/LM02/C01/T1', 'LANDSAT/LM01/C01/T1'],
#   '1978': ['LANDSAT/LM03/C01/T1', 'LANDSAT/LM02/C01/T1'],
#   '1979': ['LANDSAT/LM03/C01/T1', 'LANDSAT/LM02/C01/T1'],
#   '1980': ['LANDSAT/LM03/C01/T1', 'LANDSAT/LM02/C01/T1'],
#   '1981': ['LANDSAT/LM03/C01/T1', 'LANDSAT/LM02/C01/T1'],
#   '1982': [ 'LANDSAT/LT04/C01/T1_SR',
#             'LANDSAT/LT04/C01/T1_TOA',
#             'LANDSAT/LM03/C01/T1',
#             'LANDSAT/LM02/C01/T1'],
#   '1983': [ 'LANDSAT/LT05/C01/T1_SR',
#             'LANDSAT/LT05/C01/T1_TOA',
#             'LANDSAT/LT04/C01/T1_SR',
#             'LANDSAT/LT04/C01/T1_TOA'],
#   '1984': [ 'LANDSAT/LT05/C01/T1_SR',
#             'LANDSAT/LT05/C01/T1_TOA',
# ...
